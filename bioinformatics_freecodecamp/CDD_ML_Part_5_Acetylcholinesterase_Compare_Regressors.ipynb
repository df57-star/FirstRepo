# %% [markdown]
# # **Bioinformatics Project - Computational Drug Discovery [Part 5] Comparing Regressors**
#
# Chanin Nantasenamat
#
# ['Data Professor' YouTube channel](http://youtube.com/dataprofessor)
#
# In this Jupyter notebook, we will be building a real-life data science project that you can include in your data science portfolio. Particularly, we will be building a machine learning model using the ChEMBL bioactivity data.
#
# In Part 5, we will be comparing several ML algorithms for build regression models of acetylcholinesterase inhibitors.

# %% [markdown]
# ## **1. Import libraries**

# %%
! pip install lazypredict
# Out:
# Collecting lazypredict
#   Downloading lazypredict-0.3.0-py3-none-any.whl.metadata (24 kB)
# Requirement already satisfied: click in /usr/local/lib/python3.12/dist-packages (from lazypredict) (8.3.2)
# Requirement already satisfied: scikit-learn>=1.0 in /usr/local/lib/python3.12/dist-packages (from lazypredict) (1.6.1)
# Requirement already satisfied: pandas>=1.3 in /usr/local/lib/python3.12/dist-packages (from lazypredict) (2.2.2)
# Requirement already satisfied: tqdm>=4.0 in /usr/local/lib/python3.12/dist-packages (from lazypredict) (4.67.3)
# Requirement already satisfied: joblib>=1.0 in /usr/local/lib/python3.12/dist-packages (from lazypredict) (1.5.3)
# Requirement already satisfied: numpy>=1.21 in /usr/local/lib/python3.12/dist-packages (from lazypredict) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.3->lazypredict) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.3->lazypredict) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.3->lazypredict) (2026.1)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.0->lazypredict) (1.16.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.0->lazypredict) (3.6.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas>=1.3->lazypredict) (1.17.0)
# Downloading lazypredict-0.3.0-py3-none-any.whl (71 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.0/71.0 kB 2.5 MB/s eta 0:00:00
# Installing collected packages: lazypredict
# Successfully installed lazypredict-0.3.0

# %%
import pandas as pd
import seaborn as sns
from sklearn.model_selection import train_test_split
import lazypredict
from lazypredict.Supervised import LazyRegressor

# %% [markdown]
# ## **2. Load the data set**

# %%
! wget https://github.com/dataprofessor/data/raw/master/acetylcholinesterase_06_bioactivity_data_3class_pIC50_pubchem_fp.csv
# Out:
# --2026-04-28 02:12:10--  https://github.com/dataprofessor/data/raw/master/acetylcholinesterase_06_bioactivity_data_3class_pIC50_pubchem_fp.csv
# Resolving github.com (github.com)... 140.82.114.4
# Connecting to github.com (github.com)|140.82.114.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/dataprofessor/data/master/acetylcholinesterase_06_bioactivity_data_3class_pIC50_pubchem_fp.csv [following]
# --2026-04-28 02:12:11--  https://raw.githubusercontent.com/dataprofessor/data/master/acetylcholinesterase_06_bioactivity_data_3class_pIC50_pubchem_fp.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 8363909 (8.0M) [text/plain]
# Saving to: ‘acetylcholinesterase_06_bioactivity_data_3class_pIC50_pubchem_fp.csv’
#
# acetylcholinesteras 100%[===================>]   7.98M  --.-KB/s    in 0.02s
#
# 2026-04-28 02:12:11 (327 MB/s) - ‘acetylcholinesterase_06_bioactivity_data_3class_pIC50_pubchem_fp.csv’ saved [8363909/8363909]

# %%
df = pd.read_csv('acetylcholinesterase_06_bioactivity_data_3class_pIC50_pubchem_fp.csv')

# %%
X = df.drop('pIC50', axis=1)
Y = df.pIC50

# %% [markdown]
# ## **3. Data pre-processing**

# %%
# Examine X dimension
X.shape
# Out:
# (4695, 881)

# %%
# Remove low variance features
from sklearn.feature_selection import VarianceThreshold
selection = VarianceThreshold(threshold=(.8 * (1 - .8)))
X = selection.fit_transform(X)
X.shape
# Out:
# (4695, 137)

# %%
# Perform data splitting using 80/20 ratio
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# %% [markdown]
# ## **4. Compare ML algorithms**

# %%
# Defines and builds the lazyclassifier
clf = LazyRegressor(verbose=0,ignore_warnings=True, custom_metric=None)
models_train,train = clf.fit(X_train, X_train, Y_train, Y_train)
models_test,test = clf.fit(X_train, X_test, Y_train, Y_test)

# %%
# Performance table of the training set (80% subset)
models_train
# Out:
#                                Adjusted R-Squared  R-Squared      RMSE  \
# Model
# ExtraTreeRegressor                       0.859408   0.864538  0.571388
# DecisionTreeRegressor                    0.859408   0.864538  0.571388
# ExtraTreesRegressor                      0.859408   0.864538  0.571388
# GaussianProcessRegressor                 0.859408   0.864538  0.571388
# RandomForestRegressor                    0.822878   0.829340  0.641338
# XGBRegressor                             0.819598   0.826180  0.647249
# BaggingRegressor                         0.804288   0.811428  0.674155
# MLPRegressor                             0.757521   0.766367  0.750392
# HistGradientBoostingRegressor            0.674207   0.686094  0.869805
# LGBMRegressor                            0.654373   0.666983  0.895890
# KNeighborsRegressor                      0.633506   0.646877  0.922539
# SVR                                      0.563584   0.579506  1.006703
# NuSVR                                    0.550178   0.566590  1.022048
# GradientBoostingRegressor                0.443848   0.464139  1.136444
# TransformedTargetRegressor               0.306448   0.331752  1.269085
# LinearRegression                         0.306448   0.331752  1.269085
# Ridge                                    0.306297   0.331606  1.269223
# LassoCV                                  0.304698   0.330066  1.270685
# ElasticNetCV                             0.304390   0.329769  1.270966
# RidgeCV                                  0.303082   0.328509  1.272160
# SGDRegressor                             0.295376   0.321084  1.279174
# BayesianRidge                            0.290032   0.315935  1.284016
# HuberRegressor                           0.288388   0.314351  1.285502
# LinearSVR                                0.270178   0.296806  1.301845
# LassoLarsCV                              0.266490   0.293252  1.305131
# LassoLarsIC                              0.266290   0.293059  1.305309
# PoissonRegressor                         0.250244   0.277599  1.319505
# Lars                                     0.215824   0.244434  1.349454
# AdaBoostRegressor                        0.202533   0.231629  1.360841
# OrthogonalMatchingPursuit                0.196977   0.226275  1.365574
# OrthogonalMatchingPursuitCV              0.196977   0.226275  1.365574
# TweedieRegressor                         0.186811   0.216480  1.374190
# GammaRegressor                           0.186345   0.216031  1.374584
# LarsCV                                   0.132169   0.163831  1.419609
# DummyRegressor                          -0.037866   0.000000  1.552465
# ElasticNet                              -0.037866   0.000000  1.552465
# LassoLars                               -0.037866   0.000000  1.552465
# Lasso                                   -0.037866   0.000000  1.552465
# QuantileRegressor                       -0.049553  -0.011261  1.561181
# PassiveAggressiveRegressor              -0.170194  -0.127500  1.648466
# RANSACRegressor                         -1.298636  -1.214771  2.310394
# KernelRidge                            -14.252374 -13.695896  5.951409
#
#                                Time Taken
# Model
# ExtraTreeRegressor               0.225208
# DecisionTreeRegressor            0.172978
# ExtraTreesRegressor              7.784801
# GaussianProcessRegressor         7.721964
# RandomForestRegressor            5.236558
# XGBRegressor                     1.590882
# BaggingRegressor                 0.609492
# MLPRegressor                     7.960321
# HistGradientBoostingRegressor    1.125706
# LGBMRegressor                    0.664539
# KNeighborsRegressor              0.311248
# SVR                              3.821718
# NuSVR                            2.689547
# GradientBoostingRegressor        1.726558
# TransformedTargetRegressor       0.150055
# LinearRegression                 0.129449
# Ridge                            0.106948
# LassoCV                          3.589430
# ElasticNetCV                     3.071594
# RidgeCV                          0.252368
# SGDRegressor                     0.166229
# BayesianRidge                    0.253054
# HuberRegressor                   0.699000
# LinearSVR                        1.043864
# LassoLarsCV                      0.322760
# LassoLarsIC                      0.183305
# PoissonRegressor                 0.267523
# Lars                             0.093538
# AdaBoostRegressor                0.796882
# OrthogonalMatchingPursuit        0.050633
# OrthogonalMatchingPursuitCV      0.110331
# TweedieRegressor                 0.268341
# GammaRegressor                   0.102762
# LarsCV                           0.366487
# DummyRegressor                   0.036474
# ElasticNet                       0.047985
# LassoLars                        0.055162
# Lasso                            0.055593
# QuantileRegressor                1.598918
# PassiveAggressiveRegressor       0.103662
# RANSACRegressor                  3.709675
# KernelRidge                      1.259753

# %%
# Performance table of the test set (20% subset)
models_test
# Out:
#                                Adjusted R-Squared  R-Squared      RMSE  \
# Model
# HistGradientBoostingRegressor            0.455519   0.535044  1.059035
# RandomForestRegressor                    0.438623   0.520616  1.075341
# LGBMRegressor                            0.437692   0.519820  1.076233
# XGBRegressor                             0.436528   0.518826  1.077346
# BaggingRegressor                         0.405035   0.491933  1.107044
# NuSVR                                    0.389303   0.478499  1.121584
# SVR                                      0.389268   0.478469  1.121616
# KNeighborsRegressor                      0.371334   0.463154  1.137965
# MLPRegressor                             0.358628   0.452304  1.149408
# GradientBoostingRegressor                0.325779   0.424252  1.178475
# ExtraTreesRegressor                      0.221959   0.335596  1.265961
# DecisionTreeRegressor                    0.202740   0.319184  1.281502
# Ridge                                    0.200928   0.317637  1.282957
# LinearRegression                         0.200867   0.317585  1.283006
# TransformedTargetRegressor               0.200867   0.317585  1.283006
# RidgeCV                                  0.199737   0.316620  1.283912
# ElasticNetCV                             0.199025   0.316012  1.284484
# LassoCV                                  0.198843   0.315857  1.284629
# ExtraTreeRegressor                       0.198174   0.315285  1.285166
# SGDRegressor                             0.193046   0.310906  1.289268
# BayesianRidge                            0.191594   0.309666  1.290428
# HuberRegressor                           0.187751   0.306384  1.293492
# LassoLarsCV                              0.174967   0.295468  1.303631
# LassoLarsIC                              0.174785   0.295312  1.303775
# LinearSVR                                0.158744   0.281614  1.316386
# PoissonRegressor                         0.157829   0.280833  1.317101
# OrthogonalMatchingPursuit                0.105866   0.236459  1.357127
# OrthogonalMatchingPursuitCV              0.105866   0.236459  1.357127
# Lars                                     0.096502   0.228463  1.364214
# GammaRegressor                           0.082559   0.216556  1.374700
# TweedieRegressor                         0.080801   0.215055  1.376017
# AdaBoostRegressor                        0.070015   0.205845  1.384066
# LarsCV                                   0.019242   0.162487  1.421347
# ElasticNet                              -0.171529  -0.000421  1.553444
# DummyRegressor                          -0.171529  -0.000421  1.553444
# LassoLars                               -0.171529  -0.000421  1.553444
# Lasso                                   -0.171529  -0.000421  1.553444
# QuantileRegressor                       -0.189799  -0.016022  1.565510
# PassiveAggressiveRegressor              -0.422971  -0.215138  1.712053
# RANSACRegressor                         -1.560646  -1.186650  2.296645
# GaussianProcessRegressor                -6.016973  -4.992106  3.801841
# KernelRidge                            -16.357739 -13.822547  5.979511
#
#                                Time Taken
# Model
# HistGradientBoostingRegressor    1.068498
# RandomForestRegressor            5.181374
# LGBMRegressor                    0.556242
# XGBRegressor                     1.236599
# BaggingRegressor                 0.569036
# NuSVR                            1.614198
# SVR                              2.083723
# KNeighborsRegressor              0.141702
# MLPRegressor                     6.288366
# GradientBoostingRegressor        1.665111
# ExtraTreesRegressor              8.102211
# DecisionTreeRegressor            0.152658
# Ridge                            0.092836
# LinearRegression                 0.126285
# TransformedTargetRegressor       0.339912
# RidgeCV                          0.184487
# ElasticNetCV                     2.980330
# LassoCV                          4.313491
# ExtraTreeRegressor               0.131391
# SGDRegressor                     0.153679
# BayesianRidge                    0.277262
# HuberRegressor                   0.714501
# LassoLarsCV                      0.309159
# LassoLarsIC                      0.162943
# LinearSVR                        0.714935
# PoissonRegressor                 0.754381
# OrthogonalMatchingPursuit        0.038636
# OrthogonalMatchingPursuitCV      0.154197
# Lars                             0.096483
# GammaRegressor                   0.077823
# TweedieRegressor                 0.254969
# AdaBoostRegressor                0.730367
# LarsCV                           0.350113
# ElasticNet                       0.036585
# DummyRegressor                   0.029740
# LassoLars                        0.114995
# Lasso                            0.046506
# QuantileRegressor                2.146458
# PassiveAggressiveRegressor       0.152494
# RANSACRegressor                  2.131088
# GaussianProcessRegressor         4.071527
# KernelRidge                      1.121568

# %% [markdown]
# ## **5. Data visualization of model performance**

# %%
# Bar plot of R-squared values
import matplotlib.pyplot as plt
import seaborn as sns

#models_train["R-Squared"] = [0 if i < 0 else i for i in models_train.iloc[:,0] ]

plt.figure(figsize=(5, 10))
sns.set_theme(style="whitegrid")
ax = sns.barplot(y=models_train.index, x="R-Squared", data=models_train)
ax.set(xlim=(0, 1))
# Out:
# [(0.0, 1.0)]

# %%
# Bar plot of RMSE values
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(5, 10))
sns.set_theme(style="whitegrid")
ax = sns.barplot(y=models_train.index, x="RMSE", data=models_train)
ax.set(xlim=(0, 10))
# Out:
# [(0.0, 10.0)]

# %%
# Bar plot of calculation time
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(5, 10))
sns.set_theme(style="whitegrid")
ax = sns.barplot(y=models_train.index, x="Time Taken", data=models_train)
ax.set(xlim=(0, 10))
# Out:
# [(0.0, 10.0)]

# %%
# Bar plot of R-squared values
import matplotlib.pyplot as plt
import seaborn as sns

#model_test["R-Squared"] = [0 if i < 0 else i for i in models_test.iloc[:,0] ]

plt.figure(figsize=(5, 10))
sns.set_theme(style="whitegrid")
ax = sns.barplot(y=models_test.index, x="R-Squared", data=models_test)
ax.set(xlim=(0, 1))
# Out:
# [(0.0, 1.0)]

# %%
# Bar plot of RMSE values
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(5, 10))
sns.set_theme(style="whitegrid")
ax = sns.barplot(y=models_test.index, x="RMSE", data=models_test)
ax.set(xlim=(0, 10))
# Out:
# [(0.0, 10.0)]

# %%
# Bar plot of calculation time
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(5, 10))
sns.set_theme(style="whitegrid")
ax = sns.barplot(y=models_test.index, x="Time Taken", data=models_test)
ax.set(xlim=(0, 10))
# Out:
# [(0.0, 10.0)]
